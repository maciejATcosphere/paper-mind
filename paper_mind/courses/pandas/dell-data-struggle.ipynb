# %%
import pandas as pd

# %%
months = ['January', 'February', 'March', 
          'April', 'May', 'June', 
          'July', 'August', 'September', 
          'October'], #'November', 'December']

# January missing sentiment data
# November is already partially done NO RAW data
# December missing data

# %%
from datetime import date, timedelta

def excel_num2date(excel_num):
    return pd.to_datetime(date(1900, 1, 1) + timedelta(excel_num - 2))

# %%
month = 'February' 
path = '/home/maciej/projects/temp/SOV_data_Final.xlsx'

words = pd.read_excel(path, month, parse_cols='A:C')
words = words[words.date.notnull()]
words.date = words.date.apply(excel_num2date)

stats = pd.read_excel(path, month, parse_cols='F:P')
stats = stats[stats.Date.notnull()]
stats.Date = stats.Date.apply(pd.to_datetime)

sentiment = pd.read_excel(path, month, parse_cols='S:U')
sentiment = sentiment[sentiment.date.notnull()]
sentiment.date = sentiment.date.apply(excel_num2date)

# %%
# retrieve stuff for Dell only from words
dell_count = words[words.Word == 'Dell']

count_stats = pd.merge(dell_count, stats, left_on='date', right_on='Date')
count_stats_sentiment = pd.merge(count_stats, sentiment, left_on='date', right_on='date')

# %%
count_stats_sentiment.head(10)
# Out:
#                  date Word_x  count_x                Date Viral Reach  \
# 0 2013-02-01 00:00:00   Dell      372 2013-02-01 00:00:00      103668
# 1 2013-02-01 00:00:00   Dell      372 2013-02-01 00:00:00      103668
# 2 2013-02-01 00:00:00   Dell      372 2013-02-01 00:00:00      103668
# 3 2013-02-01 00:00:00   Dell      372 2013-02-01 00:00:00      103668
# 4 2013-02-01 00:00:00   Dell      372 2013-02-01 00:00:00      103668
# 5 2013-02-01 00:00:00   Dell      372 2013-02-01 00:00:00      103668
# 6 2013-02-02 00:00:00   Dell      683 2013-02-02 00:00:00       93740
# 7 2013-02-02 00:00:00   Dell      683 2013-02-02 00:00:00       93740
# 8 2013-02-02 00:00:00   Dell      683 2013-02-02 00:00:00       93740
# 9 2013-02-02 00:00:00   Dell      683 2013-02-02 00:00:00       93740
#
#   Organic Reach Paid Reach  Daily Engaged       Day  Lifetime Likes  \
# 0        192935    8853370           4830    Friday         1303008
# 1        192935    8853370           4830    Friday         1303008
# 2        192935    8853370           4830    Friday         1303008
# 3        192935    8853370           4830    Friday         1303008
# 4        192935    8853370           4830    Friday         1303008
# 5        192935    8853370           4830    Friday         1303008
# 6        199473    8853371           2839  Saturday         1303242
# 7        199473    8853371           2839  Saturday         1303242
# 8        199473    8853371           2839  Saturday         1303242
# 9        199473    8853371           2839  Saturday         1303242
#
#    Daily New Like  Daily New Unlike  Weekly People Talking About This  \
# 0             946               229                             15470
# 1             946               229                             15470
# 2             946               229                             15470
# 3             946               229                             15470
# 4             946               229                             15470
# 5             946               229                             15470
# 6             708               125                             16351
# 7             708               125                             16351
# 8             708               125                             16351
# 9             708               125                             16351
#
#    Weekly Page Engagement Rate             Word_y  count_y
# 0                     0.011873           Positive       20
# 1                     0.011873            Neutral      348
# 2                     0.011873  Somewhat Positive        0
# 3                     0.011873           Negative        4
# 4                     0.011873  Somewhat Negative        0
# 5                     0.011873              Mixed        0
# 6                     0.012546           Positive       22
# 7                     0.012546            Neutral      657
# 8                     0.012546  Somewhat Positive        0
# 9                     0.012546           Negative        4
